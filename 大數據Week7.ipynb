# %%
import pandas as pd
from scipy import stats

def ls2en(ls):
  ss = pd.Series(ls)
  en = stats.entropy(ss.value_counts() / ss.count(), base = 2)
  return en
ls2en([1, 0])
# stats.entropy([0.5, 0.5], base = 2)
# Out:
# 1.0

# %%
import pandas as pd
import numpy as np
from sklearn import datasets, model_selection, tree, metrics
healthcare = pd.read_csv("/content/drive/MyDrive/Colab/healthcare-dataset-stroke-data.csv")
# iris = datasets.load_iris()
# df_iris = pd.DataFrame(iris.data, columns = iris.feature_names)
# df_iris
from sklearn.preprocessing import LabelEncoder
healthcare.dropna(inplace=True)
le = LabelEncoder()
healthcare.smoking_status = le.fit_transform(healthcare.smoking_status)
healthcare.gender = le.fit_transform(healthcare.gender)
healthcare.ever_married = le.fit_transform(healthcare.ever_married)
healthcare.work_type = le.fit_transform(healthcare.work_type)
healthcare.Residence_type = le.fit_transform(healthcare.Residence_type)

myList = [row for row in healthcare.values]
myArr = np.array(myList)
X_train, X_test, y_train, y_test = model_selection.train_test_split(myArr[:, 1:11], myArr[:, 11], test_size=0.30, random_state=42)
dtc = tree.DecisionTreeClassifier()
dtc.fit(X_train, y_train)
dtc_pd = dtc.predict(X_test)
print(metrics.classification_report(y_true = y_test, y_pred = dtc_pd))
print(metrics.confusion_matrix(y_true = y_test, y_pred = dtc_pd))

tree.export_graphviz(dtc, "tree.dot")
# !dot -Tpng tree.dot -o tree.png
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95      1401
#          1.0       0.10      0.11      0.11        72
#
#     accuracy                           0.91      1473
#    macro avg       0.53      0.53      0.53      1473
# weighted avg       0.91      0.91      0.91      1473
#
# [[1329   72]
#  [  64    8]]
